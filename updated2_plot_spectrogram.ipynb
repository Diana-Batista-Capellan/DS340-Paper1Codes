# %%
#!pip uninstall -y librosa
#!pip install librosa

from IPython.display import Audio
import librosa
import librosa.display
from scipy.signal import stft
#print(dir(librosa.display))
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm
import pylab
from PIL import Image
from matplotlib.pyplot import imshow

# %matplotlib inline

from google.colab import drive
drive.mount('/content/drive')

#wav_files = '/content/drive/MyDrive/DS340W - Paper 1/wav_files/'
# Out:
# Mounted at /content/drive

# %%
y, sr = librosa.load('/content/drive/MyDrive/DS340W - Paper 1/wav_files/10000_Rock_music.wav', sr = 22050) # Use the default sampling rate of 22,050 Hz

# %%
Audio(y, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(15,2))
librosa.display.waveshow(y  = y,
                     sr     = sr,
                     #max_sr = 1000,
                     alpha  = 0.25,
                     color  = 'blue')

# %% [markdown]
# ### Apply Pre-emphasis Filter
# A pre-emphasis filter is useful in several ways: <br>(1) balance the frequency spectrum since high frequencies usually have smaller magnitudes compared to lower frequencies, <br>(2) avoid numerical problems during the Fourier transform operation and <br>(3) may also improve the Signal-to-Noise Ratio (SNR).<br>
# Source: http://haythamfayek.com/2016/04/21/speech-processing-for-machine-learning.html

# %%
pre_emphasis = 0.97
y = np.append(y[0], y[1:] - pre_emphasis * y[:-1])
plt.figure(figsize=(15,2))
librosa.display.waveshow(y  = y,
                     sr     = sr,
                     #max_sr = 1000,
                     alpha  = 0.25,
                     color  = 'red')

# %% [markdown]
# ### Fourier Transform

# %% [markdown]
# Figure 1 - Linear Amplitudes (color map)

# %%
f, t, D = stft(y, fs=sr, nperseg=2048, noverlap=512)
print('FT Shape', D.shape)

# Y-axis can be linear or log or mel
librosa.display.specshow(np.abs(D), x_axis='time', y_axis='log', cmap=cm.jet,) # Take magnitude of complex number
plt.colorbar()
plt.title('Linear Amplitude')
# Out:
# FT Shape (1025, 145)
# Text(0.5, 1.0, 'Linear Amplitude')

# %% [markdown]
# Figure 2 - Log Amplitude

# %%
log_amplitude = librosa.power_to_db(D, ref=np.max)
librosa.display.specshow(log_amplitude, x_axis='time', y_axis='log', cmap=cm.jet,)
plt.colorbar()
plt.title('Log Amplitude')
# Out:
# <ipython-input-8-cf8d26cf79a3>:1: UserWarning: power_to_db was called on complex input so phase information will be discarded. To suppress this warning, call power_to_db(np.abs(D)**2) instead.
#   log_amplitude = librosa.power_to_db(D, ref=np.max)
# Text(0.5, 1.0, 'Log Amplitude')

# %% [markdown]
# Figure 3 -Log Power (Log power spectrogram seems to be the most informative among the three)

# %%
log_amplitude = librosa.power_to_db(D**2, ref=np.max) # Square amplitude and then take log
librosa.display.specshow(log_amplitude, x_axis='time', y_axis='log', cmap=cm.jet,)
plt.colorbar()
plt.title('Log Power')
# Out:
# <ipython-input-9-0a4f3141601d>:1: UserWarning: power_to_db was called on complex input so phase information will be discarded. To suppress this warning, call power_to_db(np.abs(D)**2) instead.
#   log_amplitude = librosa.power_to_db(D**2, ref=np.max) # Square amplitude and then take log
# Text(0.5, 1.0, 'Log Power')

# %% [markdown]
# ### CQT Transform

# %%
C = librosa.cqt(y, sr=sr, n_bins=84)
print('Transform shape', C.shape)
log_power = librosa.power_to_db(C**2, ref=np.max)
librosa.display.specshow(log_power, x_axis='time', y_axis='mel', cmap=cm.jet)
# Out:
# Transform shape (84, 433)
# <ipython-input-10-0af08cc4ec11>:3: UserWarning: power_to_db was called on complex input so phase information will be discarded. To suppress this warning, call power_to_db(np.abs(D)**2) instead.
#   log_power = librosa.power_to_db(C**2, ref=np.max)

# %% [markdown]
# ### MEL Spectrogram

# %% [markdown]
# MEL scale is linear at lower frequency and logarithmic at higher frequency. - more like human hearing perception

# %%
M = librosa.feature.melspectrogram(y=y, sr=sr, fmax = sr/2, n_fft=2048, hop_length=512,
                                   n_mels = 96, power = 2) # Power = 2 refers to squared amplitude
                                                           # Hanning window by default
log_power = librosa.power_to_db(M, ref=np.max)# Covert to dB (log) scale
librosa.display.specshow(log_power, x_axis='time', y_axis='mel', cmap=cm.jet)
plt.colorbar()

# %% [markdown]
# To save and load image

# %%
pylab.figure(figsize=(3,3))
pylab.axis('off')
pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[]) # Remove the white edge
librosa.display.specshow(log_power, cmap=cm.jet)
pylab.savefig('test.jpg', bbox_inches=None, pad_inches=0)
pylab.close()

# %%
im = Image.open("test.jpg", )
np.asarray(im).shape
# Out:
# (300, 300, 3)

# %%
imshow(np.asarray(im))

# %%
import os
import librosa
from librosa import display
from matplotlib import pyplot as plt
from matplotlib import cm
import numpy as np
import pylab

# %%
WAV_DIR = '/content/drive/MyDrive/DS340W - Paper 1/wav_files/'
IMG_DIR = '/content/drive/MyDrive/DS340W - Paper 1/spectrogram_images/'
wav_files = os.listdir(WAV_DIR)

# %%
for f in wav_files[:10]:
    try:
        # Read wav-file
        y, sr = librosa.load(WAV_DIR+f, sr = 22050) # Use the default sampling rate of 22,050 Hz

        # Compute spectrogram
        M = librosa.feature.melspectrogram(y=y, sr=sr,
                                           fmax = sr/2, # Maximum frequency to be used on the on the MEL scale
                                           n_fft=2048,
                                           hop_length=512,
                                           n_mels = 96, # Set as per the Google Large-scale audio CNN paper
                                           power = 2) # Power = 2 refers to squared amplitude

        # Power in DB
        log_power = librosa.power_to_db(M, ref=np.max)# Covert to dB (log) scale

        # Plotting the spectrogram
        pylab.figure(figsize=(5,5))
        pylab.axis('off')
        pylab.axes([0., 0., 1., 1.], frameon=False, xticks=[], yticks=[]) # Remove the white edge
        librosa.display.specshow(log_power, cmap=cm.jet)
        pylab.savefig(IMG_DIR + f[:-4]+'.jpg', bbox_inches=None, pad_inches=0)
        pylab.close()

    except Exception as e:
        print(f, e)
        pass
